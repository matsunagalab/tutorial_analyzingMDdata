# %% [markdown]
# <a href="https://colab.research.google.com/github/matsunagalab/tutorial_analyzingMDdata/blob/main/00_preprocess.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Preprocess: 溶媒の削除

# %% [markdown]
# ## MDTrajのインストール

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.1.0-1/Mambaforge-23.1.0-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:19
# 🔁 Restarting kernel...

# %%
# !conda install -c conda-forge mdtraj
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 23.5.2
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.5.2
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - mdtraj
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     astunparse-1.6.3           |     pyhd8ed1ab_0          15 KB  conda-forge
#     blosc-1.21.4               |       h0f2a231_0          48 KB  conda-forge
#     c-blosc2-2.10.0            |       hb4ffafa_0         298 KB  conda-forge
#     ca-certificates-2023.5.7   |       hbcca054_0         145 KB  conda-forge
#     certifi-2023.5.7           |     pyhd8ed1ab_0         149 KB  conda-forge
# ...

# %% [markdown]
# ## T4 LysozymeのMDデータの取得
#
# solventsも含まれた全系のデータをダウンロードする。

# %%
# !gdown 1GlAC8QS1m5gWN1uXZa5DXBt5wA8C4q5N
# !gdown 1GmS7LmoFfn0j1F_iNrtLOQxB78zsiuOt
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1GlAC8QS1m5gWN1uXZa5DXBt5wA8C4q5N
# To: /content/run.pdb
# 100% 3.51M/3.51M [00:00<00:00, 131MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1GmS7LmoFfn0j1F_iNrtLOQxB78zsiuOt
# To: /content/run.dcd
# 100% 5.33M/5.33M [00:00<00:00, 127MB/s]

# %% [markdown]
# ## タンパク質(solute)部分だけ抜き出す

# %% [markdown]
# 溶媒ありのデータ (run.pdb, run.dcd) からタンパク質(solute)だけ抜き出して protein.pdb, protein.dcd として保存するワンライナー

# %%
# !python3 -c "import mdtraj as md; md.load('run.pdb').remove_solvent().save('protein.pdb')"

# %%
# !python3 -c "import mdtraj as md; md.load('run.dcd', top='run.pdb').remove_solvent().save('protein.dcd')"

# %% [markdown]
# ## alpha carbonだけ抜き出す

# %% [markdown]
# 溶媒ありのデータ (run.pdb, run.dcd) から alpha carbonだけ抜き出して ca.pdb, ca.dcd として保存するワンライナー(もっとシンプルな方法があるはず)

# %%
# !python3 -c "import mdtraj as md; md.load('run.pdb', atom_indices=md.load('run.pdb').topology.select('name CA')).save('ca.pdb')"

# %%
# !python3 -c "import mdtraj as md; md.load('run.dcd', top='run.pdb', atom_indices=md.load('run.pdb').topology.select('name CA')).save('ca.dcd')"
